# %%
import pandas as pd
df = pd.read_pickle("/home/hermuba/data0118/blast_test") #blast E.coli0.70 representing genes against local nr, no evalue limit

# %%
# %matplotlib inline
df['evalue'].plot(kind = 'hist', bins = 1000, xlim = (0, 0.001))

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.hist(list(df['evalue']), log = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-990add80f05d> in <module>()
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 plt.hist(list(df['evalue']), log = True)
#
# ~/miniconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, hold, data, **kwargs)
#    3023                       histtype=histtype, align=align, orientation=orientation,
#    3024                       rwidth=rwidth, log=log, color=color, label=label,
# -> 3025                       stacked=stacked, normed=normed, data=data, **kwargs)
#    3026     finally:
#    3027         ax._hold = washold
#
# ~/miniconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
# ...

# %%
df['evalue'].values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-ec5c95a75364> in <module>()
# ----> 1 df['evalue'].values()
#
# TypeError: 'numpy.ndarray' object is not callable
