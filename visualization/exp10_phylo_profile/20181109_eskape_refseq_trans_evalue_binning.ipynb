# %%
test_data = '/home/hermuba/data0118/refseq_bin100.csv'
import pandas as pd
d = pd.read_csv(test_data, header = 0)

# %%
# %matplotlib inline
d['count'].plot(kind = 'bar', figsize = (10,5), title = '100 equal-width bins of trans_evalue; refseq') # binning [0,1] equal width 100 refseq

# %%
test_data = '/home/hermuba/data0118/eskape_bin100.csv'
d = pd.read_csv(test_data, header = 0)
d['count'].plot(figsize = (10,5),title = '100 equal-width bins of trans_evalue; eskape' ) # binning [0,1] equal width 100 eskape
