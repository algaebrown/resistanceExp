# %%
import pandas as pd
df = pd.read_pickle("../../data/anno_sps_df")
df.columns.values
# Out:
# array(['index', 'Taxon ID', 'Genome ID', 'Genome Name', 'Antibiotic',
#        'Resistant Phenotype', 'Measurement', 'Measurement Sign',
#        'Measurement Value', 'Measurement Unit', 'Laboratory Typing Method',
#        'Laboratory Typing Method Version', 'Laboratory Typing Platform',
#        'Vendor', 'Testing Standard', 'Testing Standard Year', 'Source',
#        'Species'], dtype=object)

# %%
df.loc[df['Species'].isnull()] # What we don't want
# Out:
#       index Taxon ID    Genome ID  \
# 416     725  1439331  1.43933e+06
# 828    1468    83655      83655.1
# 1133   1994    83655      83655.1
# 1193   2102    83655      83655.1
# 2058   3614  1328337  1.32834e+06
# 2287   4012  1439331  1.43933e+06
# 2466   4339  1328337  1.32834e+06
# 2545   4481    83655      83655.1
# 2722   4773    83655      83655.1
# 2924   5128  1328337  1.32834e+06
# 2944   5167  1439331  1.43933e+06
# 3341   5867  1439331  1.43933e+06
# 3383   5940  1439331  1.43933e+06
# 3462   6096    83655      83655.1
# 3620   6378  1439331  1.43933e+06
# 3745   6609  1328337  1.32834e+06
# 3791   6683    83655      83655.1
# 4251   7470    83655      83655.1
# 4463   7863    83655      83655.1
# 4723   8310    83655      83655.1
# 5050   8890  1439331  1.43933e+06
# 5106   8975  1439331  1.43933e+06
# 5113   8994    83655      83655.1
# 5149   9056  1328337  1.32834e+06
# 5191   9127  1439331  1.43933e+06
# 5676   9971  1439331  1.43933e+06
# 5773  10143    83655      83655.1
# 6211  10936  1439331  1.43933e+06
# 6320  11116    83655      83655.1
# 6870  12052    83655      83655.1
# 6902  12095    83655      83655.1
# 7212  12626  1328337  1.32834e+06
# 7243  12668  1439331  1.43933e+06
# 7456  13032  1439331  1.43933e+06
# 7660  13362  1328337  1.32834e+06
# 7677  13386  1439331  1.43933e+06
# 8020  13946  1328337  1.32834e+06
# 8093  14082  1328337  1.32834e+06
# 8151  14187    83655      83655.1
# 8542  14884  1439331  1.43933e+06
# 8833  15389  1439331  1.43933e+06
# 8955  15626    83655      83655.1
# 9089  15838    83655      83655.1
#
#                                             Genome Name  \
# 416                          Lelliottia amnigena CHS 78
# 828   Leclercia adecarboxylata strain USDA-ARS-USMAR...
# 1133  Leclercia adecarboxylata strain USDA-ARS-USMAR...
# 1193  Leclercia adecarboxylata strain USDA-ARS-USMAR...
# 2058                              Hafnia alvei BIDMC 31
# 2287                         Lelliottia amnigena CHS 78
# 2466                              Hafnia alvei BIDMC 31
# 2545  Leclercia adecarboxylata strain USDA-ARS-USMAR...
# 2722  Leclercia adecarboxylata strain USDA-ARS-USMAR...
# 2924                              Hafnia alvei BIDMC 31
# 2944                         Lelliottia amnigena CHS 78
# 3341                         Lelliottia amnigena CHS 78
# 3383                         Lelliottia amnigena CHS 78
# 3462  Leclercia adecarboxylata strain USDA-ARS-USMAR...
# 3620                         Lelliottia amnigena CHS 78
# 3745                              Hafnia alvei BIDMC 31
# 3791  Leclercia adecarboxylata strain USDA-ARS-USMAR...
# 4251  Leclercia adecarboxylata strain USDA-ARS-USMAR...
# 4463  Leclercia adecarboxylata strain USDA-ARS-USMAR...
# 4723  Leclercia adecarboxylata strain USDA-ARS-USMAR...
# 5050                         Lelliottia amnigena CHS 78
# 5106                         Lelliottia amnigena CHS 78
# 5113  Leclercia adecarboxylata strain USDA-ARS-USMAR...
# 5149                              Hafnia alvei BIDMC 31
# 5191                         Lelliottia amnigena CHS 78
# 5676                         Lelliottia amnigena CHS 78
# 5773  Leclercia adecarboxylata strain USDA-ARS-USMAR...
# 6211                         Lelliottia amnigena CHS 78
# 6320  Leclercia adecarboxylata strain USDA-ARS-USMAR...
# 6870  Leclercia adecarboxylata strain USDA-ARS-USMAR...
# 6902  Leclercia adecarboxylata strain USDA-ARS-USMAR...
# 7212                              Hafnia alvei BIDMC 31
# 7243                         Lelliottia amnigena CHS 78
# 7456                         Lelliottia amnigena CHS 78
# 7660                              Hafnia alvei BIDMC 31
# 7677                         Lelliottia amnigena CHS 78
# 8020                              Hafnia alvei BIDMC 31
# 8093                              Hafnia alvei BIDMC 31
# 8151  Leclercia adecarboxylata strain USDA-ARS-USMAR...
# 8542                         Lelliottia amnigena CHS 78
# 8833                         Lelliottia amnigena CHS 78
# 8955  Leclercia adecarboxylata strain USDA-ARS-USMAR...
# 9089  Leclercia adecarboxylata strain USDA-ARS-USMAR...
#
#                          Antibiotic Resistant Phenotype Measurement  \
# 416                       ertapenem        Intermediate         NaN
# 828                         tylosin                 NaN         >32
# 1133                  spectinomycin                 NaN        ==16
# 1193               sulfadimethoxine                 NaN       <=256
# 2058                       cefepime           Resistant         >32
# 2287                    tigecycline         Susceptible         NaN
# 2466                  ciprofloxacin         Susceptible       <=.25
# 2545                     tilmicosin                 NaN        ==32
# 2722                      ceftiofur                 NaN       ==0.5
# 2924                    ceftazidime           Resistant         >32
# 2944  trimethoprim/sulfamethoxazole         Susceptible         NaN
# 3341                     gentamicin        Intermediate         NaN
# 3383                  ciprofloxacin        Intermediate         NaN
# 3462                   danofloxacin                 NaN      <=0.12
# 3620                     cefotaxime        Intermediate         NaN
# 3745                     tobramycin         Susceptible         <=1
# 3791                     ampicillin         Susceptible       ==0.5
# 4251                  tulathromycin                 NaN         ==4
# 4463              chlortetracycline                 NaN         ==1
# 4723                oxytetracycline                 NaN       <=0.5
# 5050           ampicillin/sulbactam           Resistant         NaN
# 5106                       imipenem        Intermediate         NaN
# 5113                   enrofloxacin                 NaN      <=0.12
# 5149                      meropenem         Susceptible       0.125
# 5191                      cefazolin        Intermediate         NaN
# 5676                      cefoxitin        Intermediate         NaN
# 5773                     gentamicin         Susceptible         <=1
# 6211                    ceftazidime        Intermediate         NaN
# 6320                       neomycin                 NaN         <=4
# 6870                       tiamulin                 NaN         >32
# 6902                     penicillin                 NaN         ==8
# 7212                    ceftriaxone           Resistant         >32
# 7243                       amikacin        Intermediate         NaN
# 7456                      meropenem        Intermediate         NaN
# 7660                     gentamicin         Susceptible         <=1
# 7677                    cephalothin           Resistant         NaN
# 8020                 nitrofurantoin         Susceptible        <=32
# 8093  trimethoprim/sulfamethoxazole                 NaN         <=1
# 8151                    clindamycin                 NaN         >16
# 8542                   levofloxacin        Intermediate         NaN
# 8833                     ampicillin        Intermediate         NaN
# 8955                    florfenicol                 NaN         ==1
# 9089  trimethoprim/sulfamethoxazole                 NaN      <=2/38
#
#      Measurement Sign Measurement Value Measurement Unit  \
# 416               NaN               nan              NaN
# 828                 >                32             mg/L
# 1133               ==                16             mg/L
# 1193               <=               256             mg/L
# 2058                >                32             mg/L
# 2287              NaN               nan              NaN
# 2466               <=               .25             mg/L
# 2545               ==                32             mg/L
# 2722               ==               0.5             mg/L
# 2924                >                32             mg/L
# 2944              NaN               nan              NaN
# 3341              NaN               nan              NaN
# 3383              NaN               nan              NaN
# 3462               <=              0.12             mg/L
# 3620              NaN               nan              NaN
# 3745               <=                 1             mg/L
# 3791               ==               0.5             mg/L
# 4251               ==                 4             mg/L
# 4463               ==                 1             mg/L
# 4723               <=               0.5             mg/L
# 5050              NaN               nan              NaN
# 5106              NaN               nan              NaN
# 5113               <=              0.12             mg/L
# 5149              NaN             0.125             mg/L
# 5191              NaN               nan              NaN
# 5676              NaN               nan              NaN
# 5773               <=                 1             mg/L
# 6211              NaN               nan              NaN
# 6320               <=                 4             mg/L
# 6870                >                32             mg/L
# 6902               ==                 8             mg/L
# 7212                >                32             mg/L
# 7243              NaN               nan              NaN
# 7456              NaN               nan              NaN
# 7660               <=                 1             mg/L
# 7677              NaN               nan              NaN
# 8020               <=                32             mg/L
# 8093               <=                 1             mg/L
# 8151                >                16             mg/L
# 8542              NaN               nan              NaN
# 8833              NaN               nan              NaN
# 8955               ==                 1             mg/L
# 9089               <=              2/38             mg/L
#
#      Laboratory Typing Method Laboratory Typing Method Version  \
# 416                       MIC                              NaN
# 828                       MIC        BOPO6F plate; cattle host
# 1133                      MIC        BOPO6F plate; cattle host
# 1193                      MIC        BOPO6F plate; cattle host
# 2058                      MIC                              NaN
# 2287                      MIC                              NaN
# 2466                      MIC                              NaN
# 2545                      MIC        BOPO6F plate; cattle host
# 2722                      MIC        BOPO6F plate; cattle host
# 2924                      MIC                              NaN
# 2944                      MIC                              NaN
# 3341                      MIC                              NaN
# 3383                      MIC                              NaN
# 3462                      MIC        BOPO6F plate; cattle host
# 3620                      MIC                              NaN
# 3745                      MIC                              NaN
# 3791                      MIC        BOPO6F plate; cattle host
# 4251                      MIC        BOPO6F plate; cattle host
# 4463                      MIC        BOPO6F plate; cattle host
# 4723                      MIC        BOPO6F plate; cattle host
# 5050                      MIC                              NaN
# 5106                      MIC                              NaN
# 5113                      MIC        BOPO6F plate; cattle host
# 5149                      MIC                              NaN
# 5191                      MIC                              NaN
# 5676                      MIC                              NaN
# 5773                      MIC        BOPO6F plate; cattle host
# 6211                      MIC                              NaN
# 6320                      MIC        BOPO6F plate; cattle host
# 6870                      MIC        BOPO6F plate; cattle host
# 6902                      MIC        BOPO6F plate; cattle host
# 7212                      MIC                              NaN
# 7243                      MIC                              NaN
# 7456                      MIC                              NaN
# 7660                      MIC                              NaN
# 7677                      MIC                              NaN
# 8020                      MIC                              NaN
# 8093                      MIC                              NaN
# 8151                      MIC        BOPO6F plate; cattle host
# 8542                      MIC                              NaN
# 8833                      MIC                              NaN
# 8955                      MIC        BOPO6F plate; cattle host
# 9089                      MIC        BOPO6F plate; cattle host
#
#      Laboratory Typing Platform                   Vendor Testing Standard  \
# 416                         NaN                      NaN              NaN
# 828                  Sensititre  TREK Diagnostic Systems             CLSI
# 1133                 Sensititre  TREK Diagnostic Systems             CLSI
# 1193                 Sensititre  TREK Diagnostic Systems             CLSI
# 2058                        NaN                      NaN              NaN
# 2287                        NaN                      NaN              NaN
# 2466                        NaN                      NaN              NaN
# 2545                 Sensititre  TREK Diagnostic Systems             CLSI
# 2722                 Sensititre  TREK Diagnostic Systems             CLSI
# 2924                        NaN                      NaN              NaN
# 2944                        NaN                      NaN              NaN
# 3341                        NaN                      NaN              NaN
# 3383                        NaN                      NaN              NaN
# 3462                 Sensititre  TREK Diagnostic Systems             CLSI
# 3620                        NaN                      NaN              NaN
# 3745                        NaN                      NaN              NaN
# 3791                 Sensititre  TREK Diagnostic Systems             CLSI
# 4251                 Sensititre  TREK Diagnostic Systems             CLSI
# 4463                 Sensititre  TREK Diagnostic Systems             CLSI
# 4723                 Sensititre  TREK Diagnostic Systems             CLSI
# 5050                        NaN                      NaN              NaN
# 5106                        NaN                      NaN              NaN
# 5113                 Sensititre  TREK Diagnostic Systems             CLSI
# 5149                        NaN                      NaN              NaN
# 5191                        NaN                      NaN              NaN
# 5676                        NaN                      NaN              NaN
# 5773                 Sensititre  TREK Diagnostic Systems             CLSI
# 6211                        NaN                      NaN              NaN
# 6320                 Sensititre  TREK Diagnostic Systems             CLSI
# 6870                 Sensititre  TREK Diagnostic Systems             CLSI
# 6902                 Sensititre  TREK Diagnostic Systems             CLSI
# 7212                        NaN                      NaN              NaN
# 7243                        NaN                      NaN              NaN
# 7456                        NaN                      NaN              NaN
# 7660                        NaN                      NaN              NaN
# 7677                        NaN                      NaN              NaN
# 8020                        NaN                      NaN              NaN
# 8093                        NaN                      NaN              NaN
# 8151                 Sensititre  TREK Diagnostic Systems             CLSI
# 8542                        NaN                      NaN              NaN
# 8833                        NaN                      NaN              NaN
# 8955                 Sensititre  TREK Diagnostic Systems             CLSI
# 9089                 Sensititre  TREK Diagnostic Systems             CLSI
#
#       Testing Standard Year Source Species
# 416                     NaN    NaN     NaN
# 828                     NaN    NaN     NaN
# 1133                    NaN    NaN     NaN
# 1193                    NaN    NaN     NaN
# 2058                    NaN    NaN     NaN
# 2287                    NaN    NaN     NaN
# 2466                    NaN    NaN     NaN
# 2545                    NaN    NaN     NaN
# 2722                    NaN    NaN     NaN
# 2924                    NaN    NaN     NaN
# 2944                    NaN    NaN     NaN
# 3341                    NaN    NaN     NaN
# 3383                    NaN    NaN     NaN
# 3462                    NaN    NaN     NaN
# 3620                    NaN    NaN     NaN
# 3745                    NaN    NaN     NaN
# 3791                    NaN    NaN     NaN
# 4251                    NaN    NaN     NaN
# 4463                    NaN    NaN     NaN
# 4723                    NaN    NaN     NaN
# 5050                    NaN    NaN     NaN
# 5106                    NaN    NaN     NaN
# 5113                    NaN    NaN     NaN
# 5149                    NaN    NaN     NaN
# 5191                    NaN    NaN     NaN
# 5676                    NaN    NaN     NaN
# 5773                    NaN    NaN     NaN
# 6211                    NaN    NaN     NaN
# 6320                    NaN    NaN     NaN
# 6870                    NaN    NaN     NaN
# 6902                    NaN    NaN     NaN
# 7212                    NaN    NaN     NaN
# 7243                    NaN    NaN     NaN
# 7456                    NaN    NaN     NaN
# 7660                    NaN    NaN     NaN
# 7677                    NaN    NaN     NaN
# 8020                    NaN    NaN     NaN
# 8093                    NaN    NaN     NaN
# 8151                    NaN    NaN     NaN
# 8542                    NaN    NaN     NaN
# 8833                    NaN    NaN     NaN
# 8955                    NaN    NaN     NaN
# 9089                    NaN    NaN     NaN

# %%
group_sps = df.groupby(['Species', 'Resistant Phenotype', 'Antibiotic']).count()
group_sps.to_excel("../../data/describe_data.xlsx")

# %%
group_pheno = df.groupby(['Resistant Phenotype', 'Antibiotic']).count()['index']
I = list(group_pheno['Intermediate'])
S = list(group_pheno['Susceptible'])
R = list(group_pheno['Resistant'])
not_S = list(group_pheno['Non-susceptible'])
not_R = list(group_pheno['Not defined'])
drug_list = list(group_pheno['Intermediate'].index)

group = pd.DataFrame([R, not_S, I, not_R, S], columns = drug_list, index = ['R', 'not_S', 'I', 'not_R', 'S']).fillna(0)

# %%
group.mean(axis = 1)
# Out:
# R        79.029851
# not_S    15.014925
# I        81.477612
# not_R     3.044776
# S        58.044776
# dtype: float64

# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
f, axarr = plt.subplots(2, sharex=True, figsize = (15,3))

plt.setp(axarr, xticks=np.arange(0.5, len(group.columns), 1), xticklabels=drug_list)
axarr[0].pcolor(group)
axarr[0].set_title('RIS distribution: COUNT')


x = np.arange(len(drug_list))
axarr[1].bar(x, group.sum())
plt.setp(plt.xticks()[1], rotation=90)
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]
