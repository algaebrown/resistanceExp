# %%
import pandas as pd

# read data
resist = pd.read_csv('~/data0118/scoary_summary/resist.csv', index_col = 0, header = 0)
gold_anno = pd.read_pickle('/home/hermuba/data0118/goldstandard/ec_rmplasmid_node_anno_df')

# subsetting genes 
resist_clusters = resist.columns.tolist()
resist_subset = gold_anno.loc[gold_anno['cluster'].isin(resist_clusters)]

# %%
resist_subset.shape # total 5340 resistant genes
# Out:
# (5340, 20)

# %%
resist_subset.index
# Out:
# Index(['562.10576.con.0026_20|562.10576', '562.10576.con.0029_10|562.10576',
#        '562.10576.con.0029_16|562.10576', '562.10576.con.0029_19|562.10576',
#        '562.10576.con.0029_44|562.10576', '562.10576.con.0029_46|562.10576',
#        '562.10576.con.0029_6|562.10576', '562.10576.con.0033_20|562.10576',
#        '562.10576.con.0037_1|562.10576', '562.10576.con.0041_12|562.10576',
#        ...
#        'NMWW01000332_5|562.19090', 'NMWW01000332_7|562.19090',
#        'NMWW01000332_8|562.19090', 'NMWW01000332_9|562.19090',
#        'NMWW01000333_10|562.19090', 'NMWW01000339_1|562.19090',
#        'NMWW01000349_6|562.19090', 'NMWW01000392_6|562.19090',
#        'NMWW01000413_7|562.19090', 'NMWW01000488_6|562.19090'],
#       dtype='object', length=5340)

# %%
# how many has domain annotation: a lot better than GO --> might provide more clue than GO 
resist_subset['domain'].count()/resist_subset.shape[0]
# Out:
# 0.61385767790262169

# %%
# when calculating domain network I had absense presence pattern of those domains for each gene
domain_abs_file = '~/data0118/domain/domain_abs_rm_plasmid'

domain_abs = pd.read_csv(domain_abs_file, header = 0, index_col = 0)

# %%
# domain names annotation from interpro
domain_anno_file = '~/data0118/interpro/all'
from Genome.goldstandard_pair.parse_interpro_out import parse
domain_anno = parse(domain_anno_file)

# %%
domain_anno = domain_anno.loc[domain_anno['ipr_accession'].notnull()]
domain_anno.drop_duplicates(subset = 'ipr_accession', inplace = True)
ipr_name_mapper = domain_anno.set_index('ipr_accession')['ipr_describe']

# %%
ipr_name_mapper.shape # map ipr accession to name
# Out:
# (8543,)

# %%
domain_abs.shape # super big file nah
# Out:
# (18601, 8543)

# %%
cont_df = pd.DataFrame(columns = domain_abs.columns, index = ['tp', 'tn', 'fp', 'fn', 'odds'])
no_resist_gene = resist_subset.shape[0]
no_genes = domain_abs.shape[0]
def contingency_table(ipr):
    tp = domain_abs.loc[resist_subset.index, ipr].sum() # how many resistant genes have that domain
    p = domain_abs[ipr].sum()
    fp = p - tp # with that domain, but not resistant gene
    
    n = no_genes - p # total genes without that domain
    fn = no_resist_gene - tp # resistant gene without that domain
    tn = n - fn
    odds = (tp+tn)/(fp+fn)
    cont_df.loc[:, ipr] = [tp, tn, fp, fn, odds]

# %%
# run for all domain
_ = [contingency_table(ipr) for ipr in domain_abs.columns]

# %%
cont_df
# Out:
#          IPR021908     IPR022369     IPR014730     IPR007495     IPR007420  \
# tp        1.000000      1.000000      0.000000      0.000000      0.000000
# tn    13261.000000  13260.000000  13255.000000  13260.000000  13259.000000
# fp        0.000000      1.000000      6.000000      1.000000      2.000000
# fn     5339.000000   5339.000000   5340.000000   5340.000000   5340.000000
# odds      2.483986      2.483333      2.479424      2.482681      2.482029
#
#          IPR010574     IPR013584     IPR017162     IPR040761     IPR011789  \
# tp        0.000000      0.000000      1.000000      0.000000      0.000000
# tn    13260.000000  13260.000000  13261.000000  13259.000000  13260.000000
# fp        1.000000      1.000000      0.000000      2.000000      1.000000
# fn     5340.000000   5340.000000   5339.000000   5340.000000   5340.000000
# odds      2.482681      2.482681      2.483986      2.482029      2.482681
#
#       ...     IPR033718     IPR003774     IPR009288     IPR010917  \
# tp    ...      0.000000      0.000000      0.000000      5.000000
# tn    ...  13258.000000  13260.000000  13259.000000  13245.000000
# fp    ...      3.000000      1.000000      2.000000     16.000000
# fn    ...   5340.000000   5340.000000   5340.000000   5335.000000
# odds  ...      2.481378      2.482681      2.482029      2.476173
#
#          IPR002792     IPR009308     IPR011130     IPR022737     IPR001661  \
# tp        0.000000      0.000000      0.000000      0.000000      0.000000
# tn    13258.000000  13260.000000  13260.000000  13260.000000  13258.000000
# fp        3.000000      1.000000      1.000000      1.000000      3.000000
# fn     5340.000000   5340.000000   5340.000000   5340.000000   5340.000000
# odds      2.481378      2.482681      2.482681      2.482681      2.481378
#
#          IPR005074
# tp        1.000000
# tn    13249.000000
# fp       12.000000
# fn     5339.000000
# odds      2.476173
#
# [5 rows x 8543 columns]

# %%
# narrow down
cont_df.loc[:, cont_df.loc['tp'] > 0]
# domain might be too rare to perform statistic analysis??
# Out:
#          IPR021908     IPR022369     IPR017162     IPR025955     IPR018117  \
# tp        1.000000      1.000000      1.000000      4.000000      3.000000
# tn    13261.000000  13260.000000  13261.000000  13252.000000  13234.000000
# fp        0.000000      1.000000      0.000000      9.000000     27.000000
# fn     5339.000000   5339.000000   5339.000000   5336.000000   5337.000000
# odds      2.483986      2.483333      2.483986      2.480075      2.467748
#
#          IPR027477     IPR022532     IPR036442     IPR002053     IPR025285  \
# tp        1.000000      1.000000      3.000000      1.000000      1.000000
# tn    13253.000000  13259.000000  13250.000000  13260.000000  13249.000000
# fp        8.000000      2.000000     11.000000      1.000000     12.000000
# fn     5339.000000   5339.000000   5337.000000   5339.000000   5339.000000
# odds      2.478773      2.482681      2.478123      2.483333      2.476173
#
#       ...     IPR003615     IPR036667     IPR019995     IPR003663  \
# tp    ...     21.000000      1.000000      1.000000      1.000000
# tn    ...  13146.000000  13252.000000  13260.000000  13255.000000
# fp    ...    115.000000      9.000000      1.000000      6.000000
# fn    ...   5319.000000   5339.000000   5339.000000   5339.000000
# odds  ...      2.423077      2.478123      2.483333      2.480075
#
#          IPR000551     IPR037171     IPR014735     IPR002104     IPR010917  \
# tp        4.000000     10.000000      2.000000     53.000000      5.000000
# tn    13251.000000  13211.000000  13257.000000  13082.000000  13245.000000
# fp       10.000000     50.000000      4.000000    179.000000     16.000000
# fn     5336.000000   5330.000000   5338.000000   5287.000000   5335.000000
# odds      2.479424      2.457435      2.482029      2.403037      2.476173
#
#          IPR005074
# tp        1.000000
# tn    13249.000000
# fp       12.000000
# fn     5339.000000
# odds      2.476173
#
# [5 rows x 2556 columns]

# %%
cont_df.loc['odds', :].sort_values(ascending = False).head() # not helpful at all, all be 2
# Out:
# IPR025668    2.487252
# IPR003325    2.486598
# IPR012933    2.485945
# IPR008490    2.485945
# IPR006142    2.485945
# Name: odds, dtype: float64

# %%
# most prevalent domain among resistant genes
prev_domain = cont_df.loc['tp', :].sort_values(ascending = False) 
pd.concat([ipr_name_mapper, prev_domain[:20]], join = 'inner', axis = 1).sort_values(by = 'tp', ascending = False)# what are the top 100 prevalent domains
# Out:
#                                                 ipr_describe     tp
# IPR027417  P-loop containing nucleoside triphosphate hydr...  217.0
# IPR036388   Winged helix-like DNA-binding domain superfamily  107.0
# IPR036390        Winged helix DNA-binding domain superfamily   80.0
# IPR009057                   Homeobox-like domain superfamily   75.0
# IPR010982  Lambda repressor-like, DNA-binding domain supe...   74.0
# IPR029063  S-adenosyl-L-methionine-dependent methyltransf...   58.0
# IPR011010      DNA breaking-rejoining enzyme, catalytic core   58.0
# IPR013762       Integrase-like, catalytic domain superfamily   55.0
# IPR012337                    Ribonuclease H-like superfamily   54.0
# IPR002104                        Integrase, catalytic domain   53.0
# IPR029044            Nucleotide-diphospho-sugar transferases   51.0
# IPR008966                        Adhesion domain superfamily   50.0
# IPR001387                Cro/C1-type helix-turn-helix domain   48.0
# IPR003593                                 AAA+ ATPase domain   48.0
# IPR036937          Fimbrial-type adhesion domain superfamily   47.0
# IPR036259                        MFS transporter superfamily   46.0
# IPR020846               Major facilitator superfamily domain   43.0
# IPR000259                      Fimbrial-type adhesion domain   43.0
# IPR001584                          Integrase, catalytic core   38.0
# IPR001296                     Glycosyl transferase, family 1   38.0

# %%
# what domains are more predominantly in resistant genes
pred_domain = (cont_df.loc['tp', :]/cont_df.loc['fp', :]).sort_values(ascending = False)
pred_domain.name = 'tp_fp'
ratio = pd.concat([ipr_name_mapper, pred_domain, prev_domain.loc[pred_domain.index]], join = 'inner', axis = 1).sort_values(by = 'tp_fp', ascending = False)# what are the top 100 prevalent domains
ratio.loc[ratio['tp'] > 2]
# Out:
#                                                 ipr_describe     tp_fp    tp
# IPR021767                  Transposon Tn21 modulator protein       inf   3.0
# IPR004111            Tetracycline repressor TetR, C-terminal       inf   3.0
# IPR003012       Tetracycline transcriptional regulator, TetR       inf   3.0
# IPR013423            Conserved hypothetical protein CHP02594       inf   3.0
# IPR020404                Protein of unknown function DUF2713       inf   3.0
# IPR018602          Gp37/putative cytoplasmic protein STM4215       inf   3.0
# IPR025140            Putative 2/3 transmembrane domain holin       inf   3.0
# IPR003586                             Hint domain C-terminal       inf   4.0
# IPR030934                  Intein C-terminal splicing region       inf   4.0
# IPR006142                                             Intein       inf   4.0
# IPR013381                     CRISPR-associated protein Cse1       inf   3.0
# IPR024165                Aminoglycoside 3-phosphotransferase       inf   3.0
# IPR002137                Beta-lactamase, class-D active site       inf   3.0
# IPR041140          Defence against restriction A, N-terminal       inf   4.0
# IPR003325                                        TerD domain  6.000000   6.0
# IPR008490                       Transposase InsH, N-terminal  5.000000   5.0
# IPR025668                             Transposase DDE domain  4.000000   8.0
# IPR009899                                    Antirestriction  4.000000   4.0
# IPR041893             Antirestriction protein ArdA, domain 3  4.000000   4.0
# IPR004042                     Intein DOD homing endonuclease  4.000000   4.0
# IPR036844                            Hint domain superfamily  4.000000   4.0
# IPR027434                                Homing endonuclease  4.000000   4.0
# IPR032126                                    LydA-like holin  4.000000   4.0
# IPR009713                Uncharacterised protein family PsiA  4.000000   4.0
# IPR009677                Protein of unknown function DUF1266  4.000000   4.0
# IPR014948  Protein of unknown function DUF1819, putative ...  3.000000   3.0
# IPR010064   Bacteriophage HK97-gp10, putative tail-component  3.000000   3.0
# IPR031817                                       DotD protein  3.000000   3.0
# IPR038140                                   DotD superfamily  3.000000   3.0
# IPR010774                Protein of unknown function DUF1364  3.000000   3.0
# ...                                                      ...       ...   ...
# IPR008640    Head domain of trimeric autotransporter adhesin  0.120000   3.0
# IPR036890     Histidine kinase/HSP90-like ATPase superfamily  0.116883   9.0
# IPR004358  Signal transduction histidine kinase-related p...  0.116279   5.0
# IPR000710                    Peptidase S6, IgA endopeptidase  0.115385   3.0
# IPR018117  DNA methylase, C-5 cytosine-specific, active site  0.111111   3.0
# IPR005467                            Histidine kinase domain  0.111111   6.0
# IPR042099          AMP-dependent synthetase-like superfamily  0.111111   3.0
# IPR007539                  Domain of unknown function DUF551  0.110169  13.0
# IPR012334                                  Pectin lyase fold  0.109091   6.0
# IPR037294                         ABC transporter, BtuC-like  0.107143   3.0
# IPR010854                 Domain of unknown function DUF1471  0.107143   3.0
# IPR000620                                        EamA domain  0.103448   3.0
# IPR025543                                       Dodecin-like  0.103448   3.0
# IPR003439                               ABC transporter-like  0.102041  20.0
# IPR017871                    ABC transporter, conserved site  0.101190  17.0
# IPR029787                                 Nucleotide cyclase  0.098039   5.0
# IPR003594                 Histidine kinase/HSP90-like ATPase  0.097222   7.0
# IPR036275                              YdgH-like superfamily  0.096774   3.0
# IPR029035        DHS-like NAD/FAD-binding domain superfamily  0.093750   3.0
# IPR016040                              NAD(P)-binding domain  0.093750   3.0
# IPR002656                                  Acyltransferase 3  0.088889   4.0
# IPR008927  6-phosphogluconate dehydrogenase-like, C-termi...  0.083333   3.0
# IPR036730  Phage P22 tailspike-like, N-terminal domain su...  0.083333   4.0
# IPR009093            Bacteriophage P22 tailspike, N-terminal  0.083333   4.0
# IPR000515  ABC transporter type 1, transmembrane domain M...  0.080808   8.0
# IPR035906                              MetI-like superfamily  0.080000   8.0
# IPR001347                              Sugar isomerase (SIS)  0.078947   3.0
# IPR015422  Pyridoxal phosphate-dependent transferase doma...  0.067568   5.0
# IPR015421  Pyridoxal phosphate-dependent transferase, maj...  0.065934   6.0
# IPR015424          Pyridoxal phosphate-dependent transferase  0.063830   6.0
#
# [758 rows x 3 columns]

# %%
cont_df.to_pickle('domain_cont_table')
