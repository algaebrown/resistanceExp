# %%
# import
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# set style
mpl.style.use("ggplot")

# plot inline
# %matplotlib inline

# %%
import pandas as pd
# load dataframe containing card_portion, card_count, cog, prevalance
cluster_detail = pd.read_pickle("../../cdhitResult/cluster_detail_tmp1010")

# %%
cluster_detail
# Out:
#               representing gene length          representing gene header  \
# Cluster 0                         6925        JMVJ01000010_255|1438681.3
# Cluster 1                         5901        JMVT01000001_309|1438693.3
# Cluster 2                         5423        AYIO01000007_135|1328432.3
# Cluster 3                         3903         JAPE01000016_72|1400157.3
# Cluster 4                         3709        JMVU01000017_403|1438694.3
# Cluster 5                         3515         JAPJ01000004_98|1328443.3
# Cluster 6                         3321  562.10576.con.0004_205|562.10576
# Cluster 7                         3262         JMVN01000033_15|1438685.3
# Cluster 8                         3206         JMVB01000013_10|1438673.3
# Cluster 9                         3163       JMUY01000001_1232|1438670.3
# Cluster 10                        3071       MPCP01000001_1727|562.12959
# Cluster 11                        2984         JJMX01000040_10|1445863.3
# Cluster 12                        2838        JMUY01000001_678|1438670.3
# Cluster 13                        2775       MPCP01000001_2775|562.12959
# Cluster 14                        2693        JMUY01000002_172|1438670.3
# Cluster 15                        2691        JAPE01000011_102|1400157.3
# Cluster 16                        2683        JMVB01000015_181|1438673.3
# Cluster 17                        2680        JMVJ01000002_451|1438681.3
# Cluster 18                        2669        JMVT01000003_584|1438693.3
# Cluster 19                        2639   562.10576.con.0017_39|562.10576
# Cluster 20                        2558         JMVW01000024_88|1438696.3
# Cluster 21                        2459          JAPR01000015_1|1328434.3
# Cluster 22                        2407            CP020058_748|562.16325
# Cluster 23                        2367       MPCO01000001_2104|562.12960
# Cluster 24                        2278         JMVJ01000031_31|1438681.3
# Cluster 25                        2255         MPCO01000010_14|562.12960
# Cluster 26                        2166          JMVB01000013_2|1438673.3
# Cluster 27                        2114        JAPE01000019_465|1400157.3
# Cluster 28                        2113        AYHT01000009_726|1328450.3
# Cluster 29                        2104        AYHT01000009_729|1328450.3
# ...                                ...                               ...
# Cluster 15920                       29         JJMX01000007_86|1445863.3
# Cluster 15921                       29          JJMX01000019_1|1445863.3
# Cluster 15922                       29         JJMX01000023_15|1445863.3
# Cluster 15923                       29         JJMX01000035_12|1445863.3
# Cluster 15924                       29          JJMX01000099_1|1445863.3
# Cluster 15925                       29         JMUZ01000016_27|1438671.3
# Cluster 15926                       29         AYHT01000011_89|1328450.3
# Cluster 15927                       29          AYIO01000019_4|1328432.3
# Cluster 15928                       29         JAPR01000021_13|1328434.3
# Cluster 15929                       29         JMVV01000003_85|1438695.3
# Cluster 15930                       29        JMVQ01000008_330|1438688.3
# Cluster 15931                       29        JMVQ01000038_197|1438688.3
# Cluster 15932                       29          MJAL01000004_9|562.13502
# Cluster 15933                       29          MJAL01000039_3|562.13502
# Cluster 15934                       28          JMVJ01000045_1|1438681.3
# Cluster 15935                       27          JMVG01000024_1|1438678.3
# Cluster 15936                       26         JJMY01000015_99|1445862.3
# Cluster 15937                       26          JMUW01000009_1|1438668.3
# Cluster 15938                       26         JJMX01000037_21|1445863.3
# Cluster 15939                       26          AYIO01000041_2|1328432.3
# Cluster 15940                       26        JMVQ01000012_145|1438688.3
# Cluster 15941                       25          JJMY01000035_1|1445862.3
# Cluster 15942                       25          MPCP01000004_1|562.12959
# Cluster 15943                       24          JJMX01000015_1|1445863.3
# Cluster 15944                       23          MJAL01000005_1|562.13502
# Cluster 15945                       22          MJAL01000023_1|562.13502
# Cluster 15946                       22          MJAL01000069_1|562.13502
# Cluster 15947                       21          JMVP01000050_1|1438687.3
# Cluster 15948                       20         JJMX01000040_21|1445863.3
# Cluster 15949                       20        JAPR01000007_802|1328434.3
#
#               mean similarity mean length  \
# Cluster 0              93.575     314.773
# Cluster 1             85.7143         843
# Cluster 2             66.6667     1807.67
# Cluster 3             95.8007          86
# Cluster 4             90.1891     337.182
# Cluster 5             97.0588     103.382
# Cluster 6             66.6667        1107
# Cluster 7             92.0713     217.467
# Cluster 8             85.7014         458
# Cluster 9             98.9908     21.3716
# Cluster 10            66.6667     1023.67
# Cluster 11            66.6667     994.667
# Cluster 12            98.6049     21.3947
# Cluster 13            66.6667         925
# Cluster 14            98.1818     48.9636
# Cluster 15            98.0218     48.9273
# Cluster 16              94.45        45.2
# Cluster 17            91.4542      146.75
# Cluster 18            92.3732     140.474
# Cluster 19            66.6667     879.667
# Cluster 20            97.2221     2.52151
# Cluster 21            90.3367     30.6667
# Cluster 22            89.9067       92.25
# Cluster 23            94.1174      84.963
# Cluster 24            82.4983     379.667
# Cluster 25            87.9456     250.556
# Cluster 26                 90        23.8
# Cluster 27            97.8425     40.6538
# Cluster 28            66.6667     704.333
# Cluster 29            66.6667     701.333
# ...                       ...         ...
# Cluster 15920         66.6667     9.66667
# Cluster 15921         87.7389     3.22222
# Cluster 15922         66.6667     9.66667
# Cluster 15923         83.3333     4.83333
# Cluster 15924         66.6667     9.66667
# Cluster 15925         96.6667    0.966667
# Cluster 15926         88.8889     3.22222
# Cluster 15927         66.6667     9.66667
# Cluster 15928         66.6667     9.66667
# Cluster 15929         66.6667     9.66667
# Cluster 15930         66.6667     9.66667
# Cluster 15931         66.6667     9.66667
# Cluster 15932         83.3333     4.83333
# Cluster 15933         66.6667     9.66667
# Cluster 15934         66.6667     9.33333
# Cluster 15935         66.6667           9
# Cluster 15936         85.7143     3.71429
# Cluster 15937         66.6667     8.66667
# Cluster 15938         66.6667     8.66667
# Cluster 15939         66.6667     8.66667
# Cluster 15940         66.6667     8.66667
# Cluster 15941            87.5       3.125
# Cluster 15942         66.6667     8.33333
# Cluster 15943         83.3333           4
# Cluster 15944         66.6667     7.66667
# Cluster 15945         66.6667     7.33333
# Cluster 15946         66.6667     7.33333
# Cluster 15947         66.6667           7
# Cluster 15948         83.3333     3.33333
# Cluster 15949         66.6667     6.66667
#
#                                                           member  \
# Cluster 0      ,JMVT01000001_310|1438693.3,JMVT01000001_310|1...
# Cluster 1      ,JMVT01000001_309|1438693.3,JMVT01000001_309|1...
# Cluster 2      ,AYIO01000007_135|1328432.3,AYIO01000007_135|1...
# Cluster 3      ,JAPE01000016_72|1400157.3,JMVT01000009_1|1438...
# Cluster 4      ,JMVT01000007_404|1438693.3,JMVT01000008_1|143...
# Cluster 5      ,JAPJ01000004_98|1328443.3,JAPJ01000004_98|132...
# Cluster 6      ,562.10576.con.0004_205|562.10576,562.10576.co...
# Cluster 7      ,JJMX01000035_1|1445863.3,JJMX01000061_1|14458...
# Cluster 8      ,JMVB01000013_10|1438673.3,JMVB01000013_10|143...
# Cluster 9      ,JMUY01000001_1232|1438670.3,JAPE01000009_453|...
# Cluster 10     ,MPCP01000001_1727|562.12959,MPCP01000001_1727...
# Cluster 11     ,JJMX01000040_10|1445863.3,JJMX01000040_10|144...
# Cluster 12     ,JMUY01000001_678|1438670.3,JMUY01000001_678|1...
# Cluster 13     ,MPCP01000001_2775|562.12959,MPCP01000001_2775...
# Cluster 14     ,JMUY01000002_172|1438670.3,JMUY01000002_172|1...
# Cluster 15     ,JAPE01000011_102|1400157.3,JAPJ01000005_81|13...
# Cluster 16     ,JMVB01000015_181|1438673.3,JMVF01000006_102|1...
# Cluster 17     ,JMVJ01000002_451|1438681.3,CP021175_2601|562....
# Cluster 18     ,JMVT01000003_584|1438693.3,JMVT01000003_584|1...
# Cluster 19     ,562.10576.con.0017_39|562.10576,562.10576.con...
# Cluster 20     ,JAPE01000017_257|1400157.3,JAPE01000019_1|140...
# Cluster 21     ,JMVJ01000007_1|1438681.3,JMVJ01000042_1|14386...
# Cluster 22     ,CP020058_748|562.16325,JMVV01000008_170|14386...
# Cluster 23     ,MPCO01000001_2104|562.12960,CP020055_209|562....
# Cluster 24     ,JMVJ01000031_31|1438681.3,CP020051_108|562.16...
# Cluster 25     ,MPCO01000010_14|562.12960,JMVO01000027_9|1438...
# Cluster 26     ,JMVB01000013_2|1438673.3,JMVB01000013_2|14386...
# Cluster 27     ,JAPE01000019_465|1400157.3,JAPJ01000001_71|13...
# Cluster 28     ,AYHT01000009_726|1328450.3,AYHT01000009_726|1...
# Cluster 29     ,AYHT01000009_729|1328450.3,AYHT01000009_729|1...
# ...                                                          ...
# Cluster 15920  ,JJMX01000007_86|1445863.3,JJMX01000007_86|144...
# Cluster 15921  ,JJMX01000019_1|1445863.3,JMVQ01000014_1|14386...
# Cluster 15922  ,JJMX01000023_15|1445863.3,JJMX01000023_15|144...
# Cluster 15923  ,JJMX01000035_12|1445863.3,JMVN01000033_26|143...
# Cluster 15924  ,JJMX01000099_1|1445863.3,JJMX01000099_1|14458...
# Cluster 15925  ,JMUZ01000016_27|1438671.3,JMVK01000014_4|1438...
# Cluster 15926  ,AYHT01000011_89|1328450.3,CP021175_1386|562.1...
# Cluster 15927  ,AYIO01000019_4|1328432.3,AYIO01000019_4|13284...
# Cluster 15928  ,JAPR01000021_13|1328434.3,JAPR01000021_13|132...
# Cluster 15929  ,JMVV01000003_85|1438695.3,JMVV01000003_85|143...
# Cluster 15930  ,JMVQ01000008_330|1438688.3,JMVQ01000008_330|1...
# Cluster 15931  ,JMVQ01000038_197|1438688.3,JMVQ01000038_197|1...
# Cluster 15932  ,MJAL01000004_9|562.13502,MJAL01000017_1|562.1...
# Cluster 15933  ,MJAL01000039_3|562.13502,MJAL01000039_3|562.1...
# Cluster 15934  ,JMVJ01000045_1|1438681.3,JMVJ01000045_1|14386...
# Cluster 15935  ,JMVG01000024_1|1438678.3,JMVG01000024_1|14386...
# Cluster 15936  ,JJMY01000015_99|1445862.3,JJMY01000015_99|144...
# Cluster 15937  ,JMUW01000009_1|1438668.3,JMUW01000009_1|14386...
# Cluster 15938  ,JJMX01000037_21|1445863.3,JJMX01000037_21|144...
# Cluster 15939  ,AYIO01000041_2|1328432.3,AYIO01000041_2|13284...
# Cluster 15940  ,JMVQ01000012_145|1438688.3,JMVQ01000012_145|1...
# Cluster 15941  ,JJMY01000035_1|1445862.3,JJMY01000070_1|14458...
# Cluster 15942  ,MPCP01000004_1|562.12959,MPCP01000004_1|562.1...
# Cluster 15943  ,JJMX01000015_1|1445863.3,JJMX01000084_4|14458...
# Cluster 15944  ,MJAL01000005_1|562.13502,MJAL01000005_1|562.1...
# Cluster 15945  ,MJAL01000023_1|562.13502,MJAL01000023_1|562.1...
# Cluster 15946  ,MJAL01000069_1|562.13502,MJAL01000069_1|562.1...
# Cluster 15947  ,JMVP01000050_1|1438687.3,JMVP01000050_1|14386...
# Cluster 15948  ,JJMX01000040_21|1445863.3,JJMX01000046_16|144...
# Cluster 15949  ,JAPR01000007_802|1328434.3,JAPR01000007_802|1...
#
#                card_portion  card_count  cog  prevalance
# Cluster 0               0.0         0.0  NaN    0.118644
# Cluster 1               0.0         0.0  NaN    0.033898
# Cluster 2               0.0         0.0  NaN    0.016949
# Cluster 3               0.0         0.0  NaN    0.084746
# Cluster 4               0.0         0.0  NaN    0.033898
# Cluster 5               0.0         0.0  NaN    0.186441
# Cluster 6               0.0         0.0  NaN    0.016949
# Cluster 7               0.0         0.0    U    0.033898
# Cluster 8               0.0         0.0    Q    0.033898
# Cluster 9               0.0         0.0    Q    0.779661
# Cluster 10              0.0         0.0    Q    0.016949
# Cluster 11              0.0         0.0    U    0.016949
# Cluster 12              0.0         0.0  NaN    0.305085
# Cluster 13              0.0         0.0    Q    0.016949
# Cluster 14              0.0         0.0  NaN    0.305085
# Cluster 15              0.0         0.0  NaN    0.288136
# Cluster 16              0.0         0.0  NaN    0.101695
# Cluster 17              0.0         0.0  NaN    0.067797
# Cluster 18              0.0         0.0  NaN    0.084746
# Cluster 19              0.0         0.0   MU    0.016949
# Cluster 20              0.0         0.0    M    0.491525
# Cluster 21              0.0         0.0  NaN    0.050847
# Cluster 22              0.0         0.0  NaN    0.050847
# Cluster 23              0.0         0.0  NaN    0.135593
# Cluster 24              0.0         0.0    L    0.033898
# Cluster 25              0.0         0.0    L    0.050847
# Cluster 26              0.0         0.0    I    0.033898
# Cluster 27              0.0         0.0    L    0.271186
# Cluster 28              0.0         0.0    L    0.016949
# Cluster 29              0.0         0.0    L    0.016949
# ...                     ...         ...  ...         ...
# Cluster 15920           0.0         0.0  NaN    0.016949
# Cluster 15921           0.0         0.0  NaN    0.050847
# Cluster 15922           0.0         0.0  NaN    0.016949
# Cluster 15923           0.0         0.0  NaN    0.033898
# Cluster 15924           0.0         0.0  NaN    0.016949
# Cluster 15925           0.0         0.0  NaN    0.169492
# Cluster 15926           0.0         0.0  NaN    0.050847
# Cluster 15927           0.0         0.0  NaN    0.016949
# Cluster 15928           0.0         0.0  NaN    0.016949
# Cluster 15929           0.0         0.0  NaN    0.016949
# Cluster 15930           0.0         0.0  NaN    0.016949
# Cluster 15931           0.0         0.0  NaN    0.016949
# Cluster 15932           0.0         0.0  NaN    0.016949
# Cluster 15933           0.0         0.0  NaN    0.016949
# Cluster 15934           0.0         0.0  NaN    0.016949
# Cluster 15935           0.0         0.0  NaN    0.016949
# Cluster 15936           0.0         0.0  NaN    0.033898
# Cluster 15937           0.0         0.0  NaN    0.016949
# Cluster 15938           0.0         0.0    K    0.016949
# Cluster 15939           0.0         0.0  NaN    0.016949
# Cluster 15940           0.0         0.0  NaN    0.016949
# Cluster 15941           0.0         0.0  NaN    0.016949
# Cluster 15942           0.0         0.0  NaN    0.016949
# Cluster 15943           0.0         0.0  NaN    0.016949
# Cluster 15944           0.0         0.0  NaN    0.016949
# Cluster 15945           0.0         0.0  NaN    0.016949
# Cluster 15946           0.0         0.0  NaN    0.016949
# Cluster 15947           0.0         0.0  NaN    0.016949
# Cluster 15948           0.0         0.0  NaN    0.016949
# Cluster 15949           0.0         0.0  NaN    0.016949
#
# [15950 rows x 9 columns]

# %%
df = pd.read_pickle("../../cdhitResult/ec0913_df")

# core genome, accessory genome
gene_count = df.sum(axis = 0)
core = gene_count.loc[gene_count == 59] 
accessory = gene_count.loc[gene_count != 59]
unique = gene_count.loc[gene_count == 1]
print(len(core), len(accessory), len(unique))

# determine how conserved they are: they are all similar
core_sim = cluster_detail.loc[core.index.values, 'mean similarity'].mean()
acc_sim = cluster_detail.loc[accessory.index.values, 'mean similarity'].mean()
print(core_sim, acc_sim)

# determine the length gap between representing sequence and other members of the family
core_len_gap_se = cluster_detail.loc[core.index.values, 'representing gene length'] - cluster_detail.loc[core.index.values, 'mean length']
accessory_len_gap_se = cluster_detail.loc[accessory.index.values, 'representing gene length'] - cluster_detail.loc[accessory.index.values, 'mean length']
print(core_len_gap_se.mean(), accessory_len_gap_se.mean())
# Out:
# 2874 13076 5522
# 98.943429783 82.2062326726
# 329.147581819 224.352406137

# %%
# count cog
def cog_dis(df): # parse cog
    result = pd.DataFrame(np.zeros((1,26)), columns = ['J','A','K','L','B','D','Y','V','T','M','N','Z','W','U','O','C','G','E','F','H','I','P','Q','R','S','NaN'])
    cog = list(df.loc[df['cog'].notnull()]['cog'])
    for str in cog:
        for s in str:
            result[s] += 1
    result['NaN'] = df.shape[0]-len(cog)
    return(result)

# %%
# apply count cog to all of them!
cog_seperate = pd.DataFrame(columns = ['J','A','K','L','B','D','Y','V','T','M','N','Z','W','U','O','C','G','E','F','H','I','P','Q','R','S','NaN'])
for percentile in range(11):
    sub_df = cluster_detail.loc[cluster_detail['prevalance'].apply(lambda x: math.floor(x/0.1)) == percentile]
    cog_seperate = cog_seperate.append(cog_dis(sub_df), ignore_index = True)

# %%
# move legend to side
cog_seperate.plot(kind = 'bar', figsize = (10,5), xticks= cog_seperate.index, stacked=True, colormap = 'tab20b').legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
# pangenome distribution with card category
card_seperate = pd.DataFrame(columns = ['card', 'no card'])
for percentile in range(11):
    sub_df = cluster_detail.loc[cluster_detail['prevalance'].apply(lambda x: math.floor(x/0.1)) == percentile]
    card = sub_df.loc[sub_df['card_count'] > 0].shape[0]
    no_card = sub_df.shape[0]-card
    card_seperate = card_seperate.append({'card':card,
                                         'no card': no_card}, ignore_index = True)

# %%
card_seperate.plot(kind = 'bar', figsize = (10,5), xticks= card_seperate.index, stacked=True,logy = True, colormap = 'tab20b').legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
fig, ax = plt.subplots()
cluster_detail['card_portion'].hist(bins = 100, ax = ax)
ax.set_yscale('log')
ax.set_ylabel("log count")
ax.set_xlabel("freqency of containing card gene in a cluster")

# %%
fig, ax = plt.subplots()
cluster_detail['card_count'].hist(bins = 10, ax = ax)
ax.set_yscale('log')
ax.set_ylabel("log count")
ax.set_xlabel("card gene count")

# %%
ct = pd.DataFrame(columns = ['core', 'accessory', 'pangenome'])
i = 0
for index, row in df.iterrows():
    i = i + 1
    count = df.iloc[:i, :]
    
    count = count.sum(axis = 0)
    
    al = len(count.loc[count > 0])
    cr = len(count.loc[count == i])
    acc = al - cr ######
    ct.loc[index, 'core'] = cr
    ct.loc[index, 'accessory'] = acc
    ct.loc[index, 'pangenome'] = al

# %%
ct.plot(xticks = np.arange(1, 59, 1), use_index = False, figsize = (15,10))

# %%
ct.plot(xticks = np.arange(1, 59, 1), use_index = False, figsize = (15,10))

# %%
# core and accessory cog difference
core_cog = cog_dis(cluster_detail.loc[cluster_detail['prevalance']==1])
acc_cog = cog_dis(cluster_detail.loc[cluster_detail['prevalance']<1])
both_cog = core_cog.append(acc_cog, ignore_index = True)
both_cog.rename(index = {0:'core', 1:'accessory'})
# Out:
#                J    A      K      L    B     D    Y      V      T      M  \
# core       168.0  1.0  166.0  116.0  0.0  27.0  0.0   31.0  120.0  157.0
# accessory   40.0  2.0  472.0  862.0  0.0  53.0  0.0  155.0  130.0  624.0
#
#            ...       G      E     F      H     I      P     Q      R      S  \
# core       ...   228.0  273.0  79.0  117.0  67.0  189.0  29.0  191.0  278.0
# accessory  ...   418.0  170.0  54.0   74.0  67.0  233.0  71.0  562.0  751.0
#
#             NaN
# core        249
# accessory  7628
#
# [2 rows x 26 columns]

# %%
both_cog.plot(kind = 'bar', figsize = (10,5), stacked=True, colormap = 'tab20b').legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
both_cog.transpose().plot(kind = 'pie', figsize = (10,5), subplots = True, stacked=True, colormap = 'tab20b', legend = False)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f76b0b720f0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f76b0b4d390>], dtype=object)

# %%
both_cog.sum(axis = 1)
# Out:
# 0     2922.0
# 1    13468.0
# dtype: float64

# %%
freq_cog = both_cog
freq_cog.iloc[0,:] = both_cog.iloc[0,:]/2922
freq_cog.iloc[1,:] = both_cog.iloc[1,:]/13468

# %%
(freq_cog.iloc[0,:]/freq_cog.iloc[1,:]).sort_values()
# Out:
# W       0.000000
# NaN     0.150457
# U       0.401203
# N       0.561373
# L       0.620260
# V       0.921834
# M       1.159679
# R       1.566462
# K       1.621022
# S       1.706191
# Q       1.882619
# A       2.304586
# D       2.348069
# G       2.514094
# P       3.738770
# T       4.254620
# I       4.609172
# C       5.882424
# O       6.016182
# F       6.743048
# H       7.287474
# E       7.401788
# J      19.358522
# B            NaN
# Y            NaN
# Z            NaN
# dtype: float64

# %%
freq_cog.plot(kind = 'area', figsize = (10,5), stacked=True, colormap = 'tab20b').legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
eli_nan = both_cog.iloc[:, 0:25] # 2573, 5840
eli_nan.sum(axis = 1)
# Out:
# 0    2673.0
# 1    5840.0
# dtype: float64

# %%
eli_nan.sum(axis = 1)
elif_cog = eli_nan
elif_cog.iloc[0,:] = both_cog.iloc[0,:]/2673
elif_cog.iloc[1,:] = both_cog.iloc[1,:]/5840

# %%
(elif_cog.iloc[0,:]/elif_cog.iloc[1,:]).sort_values()
# Out:
# W    0.000000
# U    0.190176
# N    0.266099
# L    0.294012
# V    0.436962
# M    0.549704
# R    0.742525
# K    0.768387
# S    0.808758
# Q    0.892388
# A    1.092406
# D    1.113017
# G    1.191715
# P    1.772229
# T    2.016749
# I    2.184811
# C    2.788350
# O    2.851753
# F    3.196298
# H    3.454363
# E    3.508550
# J    9.176207
# B         NaN
# Y         NaN
# Z         NaN
# dtype: float64

# %%
elif_cog.plot(kind = 'area', figsize = (10,5), stacked=True, colormap = 'tab20b').legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
elif_cog.plot(kind = 'bar', figsize = (10,5), stacked=True, colormap = 'tab20b').legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
elif_cog.transpose().plot(kind = 'pie', figsize = (10,5), subplots = True, stacked=True, colormap = 'tab20b', legend = False)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f76b0d87978>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f76b0169eb8>], dtype=object)
