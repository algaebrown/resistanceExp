# %%
import pandas as pd
from Genome.goldstandard_pair.lls import *

# %%
gd = '/home/hermuba/data0118/goldstandard/tf_intersectGO.smpl'
gold= read_gold(gd)

# %%
all_chunks = read_net_by_chunk('/home/hermuba/data0118/domain_weight_mutual')
all_df = merge_net_with_all_chunks(gold, all_chunks)

# %%
all_df.head()
# Out:
#                           gene_one                          gene_two  \
# 0  562.22521.con.0022_55|562.22521  562.23576.con.0014_134|562.23576
# 1  562.22653.con.0011_41|562.22653   562.23487.con.0051_11|562.23487
# 2  562.22653.con.0011_41|562.22653    562.23714.con.0031_6|562.23714
# 3  562.22653.con.0011_41|562.22653        FLWH01000008_305|562.12962
# 4  562.22653.con.0011_41|562.22653         JMUY01000019_15|1438670.3
#
#    goldstandard  weighted_mutual
# 0             0     1.506632e-09
# 1             0     7.746610e-08
# 2             0     1.978199e-08
# 3             0     1.640511e-08
# 4             0     6.117453e-09

# %%
all_df.to_csv('~/data0118/domain_GO_smpl') # this step is f slow

# %%
def map_lls(lls_score, true_thres, slope, intercept):
    x = np.array([interval.mid for interval in lls_score.index])
    y = slope * x + intercept

    new_lls = pd.Series(index = lls_score.index, data = y)
    new_lls[:true_thres] = 0
    return(new_lls)

# %%
def try_diff_lls_thres(all_df):
    # start from 3, 6, 12, 24, 48, 96, 132, 264, 528, 1056
    tradeoff = pd.DataFrame(columns = ['thres', 'coverage', 'PPV'])
    
    try_list = np.sort(all_chunk['lls'].unique())[:-1]
    for t in try_list:
        cov, PPV = PPV_coverage(t, all_df)
        tradeoff.loc[t] = [t, cov, PPV]
    return(tradeoff)

# %%
def lls_for_domain(all_df, score):
    #drop = ['gene_one', 'gene_two', 'goldstandard']
    #score = list(set(all_df.columns) - set(drop))[0] # context has two kinds of scores


    all_df['cut_mutual'] = pd.qcut(all_df[score],  250, duplicates = 'raise')



    grouped = all_df.groupby(by = ['goldstandard', 'cut_mutual']).count()['gene_one']
    grouped = grouped.fillna(0)
    lls_score = grouped[1]/grouped[0]/(grouped[1].sum()/grouped[0].sum())
    #lls.plot()

    return(lls_score)

# %%
# %matplotlib inline
def wrap_for_diff_score(score, all_chunk):
    lls_score = lls_for_domain(all_chunk, score)
    true_thres, slope, intercept = lls_regress_thres(lls_score)
    new_lls = map_lls(lls_score, true_thres, slope, intercept)
    all_chunk = map_score_to_lls(all_chunk, new_lls, score)
    tradeoff = try_diff_lls_thres(all_chunk)
    return(new_lls, all_chunk,lls_score, tradeoff, true_thres)

# %%
new_lls, all_chunk,lls_score, tradeoff, true_thres = wrap_for_diff_score('weighted_mutual', all_df)

# %%
lls_score.plot()
new_lls.plot() #bin = 300, tradeoff does not fit

# %%
lls_score.plot()
new_lls.plot() #bin = 250 BEST

# %%
lls_score.plot()
new_lls.plot() #bin = 200 sucks

# %%
lls_score.plot()
new_lls.plot() # bin = 150 # bin = 200 sucks

# %%
lls_score.plot()
new_lls.plot() # bins = 100

# %%
lls_score.plot()
new_lls.plot() # bins = 100 # if remove LLS < 3 make it 0

# %%
true_thres.right
# Out:
# 3.94e-07

# %%
np.sort(all_chunk['lls'].unique())[:-1]
# Out:
# array([ 0.        , 12.7870623 , 13.09025587])

# %%
tradeoff
# Out:
#                thres  coverage       PPV
# 0.000000    0.000000  0.290051  0.522282
# 17.425933  17.425933  0.258421  0.594500
# 17.458249  17.458249  0.219937  0.665623
# 17.571357  17.571357  0.179886  0.699417
# 17.860190  17.860190  0.132197  0.841448
# 19.153763  19.153763  0.071387  0.937656

# %%
tradeoff.to_csv('~/data0118/PPV_coverage/domain_250')

# %%
import matplotlib.pyplot as plt
plt.plot(tradeoff['coverage'], tradeoff['PPV'], '-') 
plt.plot(tradeoff['coverage'], tradeoff['PPV'], '+') 
plt.xlabel('coverage')
plt.ylabel('PPV')
# Out:
# Text(0, 0.5, 'PPV')

# %%
all_chunk.head()
# Out:
#                           gene_one                          gene_two  \
# 0  562.22521.con.0022_55|562.22521  562.23576.con.0014_134|562.23576
# 1  562.22653.con.0011_41|562.22653   562.23487.con.0051_11|562.23487
# 2  562.22653.con.0011_41|562.22653    562.23714.con.0031_6|562.23714
# 3  562.22653.con.0011_41|562.22653        FLWH01000008_305|562.12962
# 4  562.22653.con.0011_41|562.22653         JMUY01000019_15|1438670.3
#
#    goldstandard  weighted_mutual            cut_mutual  lls    ans
# 0             0     1.506632e-09  (1.51e-09, 1.55e-09]  0.0  False
# 1             0     7.746610e-08  (7.31e-08, 7.89e-08]  0.0  False
# 2             0     1.978199e-08  (1.95e-08, 2.03e-08]  0.0  False
# 3             0     1.640511e-08  (1.62e-08, 1.68e-08]  0.0  False
# 4             0     6.117453e-09  (6.03e-09, 6.21e-09]  0.0  False

# %%
all_chunk.shape
# Out:
# (100022, 7)

# %%
net_elimi = all_chunk.loc[all_chunk['lls']>=3]

# %%
net_elimi.shape
# Out:
# (2401, 7)

# %%
# test nx
from networkx.convert_matrix import from_pandas_edgelist
G = from_pandas_edgelist(net_elimi, source = 'gene_one', target = 'gene_two', edge_attr = 'lls')

# %%
G.number_of_nodes()
# Out:
# 2962

# %%
G.number_of_edges()
# Out:
# 2379

# %%
def map_lls_to_whole_data(net, new_lls, score, true_thres, output_file):
    '''
    map LLS to whole data and save to file
    drop LLS < 3: their LLS will be zero so no information :(
    '''

    from networkx.convert_matrix import from_pandas_edgelist
    from networkx import write_edgelist

    n = 0
    all_chunks = read_net_by_chunk(net)
    for chunk in all_chunks:
        # drop LLS < 3 by excluding thres:
        dropped = chunk.loc[chunk[score] > true_thres.right]
        
        # map new_lls to df score
        mapped = map_score_to_lls(dropped, new_lls, score)
        
        # convert to edgelist
        G = from_pandas_edgelist(mapped, source = 'gene_one', target = 'gene_two', edge_attr = 'lls')
        # write to file
        with open(output_file, 'ab') as f:
            write_edgelist(G, f, data = True)
        print('done with chunk ' + str(n))

        n += 1

# %%
output = '/home/hermuba/data0118/network1122/domain_lls_edgelist'
net = '/home/hermuba/data0118/domain_weight_mutual'
# map LLS_reg back to each "whole" network
map_lls_to_whole_data(net, new_lls, 'weighted_mutual', true_thres, output)
# Out:
# done with chunk 0
# done with chunk 1
# done with chunk 2
# done with chunk 3
# done with chunk 4
# done with chunk 5
# done with chunk 6
# done with chunk 7
# done with chunk 8
# done with chunk 9
# done with chunk 10
# done with chunk 11
# done with chunk 12
# done with chunk 13
# done with chunk 14
# done with chunk 15
# done with chunk 16
# done with chunk 17
# done with chunk 18
# done with chunk 19
# done with chunk 20
# done with chunk 21
# done with chunk 22
# done with chunk 23
# done with chunk 24
# done with chunk 25
# done with chunk 26
# done with chunk 27
# done with chunk 28
# done with chunk 29
# done with chunk 30
# done with chunk 31
# done with chunk 32
# done with chunk 33
# done with chunk 34
# done with chunk 35
# done with chunk 36
# done with chunk 37
# done with chunk 38
# done with chunk 39
# done with chunk 40
# done with chunk 41
# done with chunk 42
# done with chunk 43
# done with chunk 44
# done with chunk 45
# done with chunk 46
# done with chunk 47
# ...

# %%
true_thres.left
# Out:
# 3.03e-07

# %%
def return_stats(d):
    '''
    input: dataframe from `to_df`
    output: stats representing true and false interacting pairs
    '''
    
    d.boxplot(column = ['weighted_mutual'], by = 'goldstandard')
    group_d = d.groupby(by = 'goldstandard')
    
    return(group_d[['weighted_mutual']].describe())
def kde_d(d):
    
    group_d = d.groupby(by = 'goldstandard')
    
    group_d['weighted_mutual'].plot(kind = 'kde', legend = True, title = 'weighted_mutual')
    

def LLS(d, score):
    # seperate mutual info score into 100 categories
    d['cut_mutual'] = pd.qcut(d[score],  200)
    grouped = d.groupby(by = ['goldstandard', 'cut_mutual']).count()['gene_one']
    grouped = grouped.fillna(0)
    lls = grouped[1]/grouped[0]/(grouped[1].sum()/grouped[0].sum())
    lls.plot()
    return(lls)
